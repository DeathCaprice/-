# %% [markdown]
# # モデルチューニング

# %% [markdown]
# # LightGBMのハイパーパラメータのチューニング
# ## ハイパーパラメータの自動チューニング

# %%
# Google Driveと接続を行います。これを行うことで、Driveにあるデータにアクセスできるようになります。
# 下記セルを実行すると、Googleアカウントのログインを求められますのでログインしてください。
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #### ライブラリのインポート

# %%
import numpy as np
import pandas as pd
import os
import pickle
import gc

# 分布確認  anacondaでは、一先ず、コメントにする。
#import pandas_profiling as pdp

# 可視化
import matplotlib.pyplot as plt

# 前処理
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder, OneHotEncoder

# バリデーション
from sklearn.model_selection import train_test_split, KFold, StratifiedKFold, GroupKFold

# 評価指標
from sklearn.metrics import accuracy_score, roc_auc_score, confusion_matrix

# モデリング: lightgbm
import lightgbm as lgb

import numpy as np

import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %% [markdown]
# #### ファイルの読み込みと特徴量エンジニアリング

# %%
df_train = pd.read_csv("Bank Churn/train.csv")

### OneHotEncoderのインスタンスを作成し、sparse=Falseで密行列を指定
ohe_Gender=OneHotEncoder(sparse=False)


### OneHotEncoderを訓練データの"Gendet"列に適させる

ohe_Gender.fit(df_train[["Gender"]])

### OneHotエンコーディングされた特徴量を含むDataFrameを作成し、列名を指定
tmp_Gender = pd.DataFrame(
    ### OneHotエンコーディングを実行し、結果をDataFrameに保存
    ohe_Gender.transform(df_train[["Gender"]]),
    ### 列名設定
    columns=["Gender_{}".format(i) for i in ohe_Gender.categories_[0]],
)


### 元のデータフレームとOneHotエンコーディングされた特徴量を結合
df_train = pd.concat([df_train, tmp_Gender], axis=1)

### "Gender"列とOne-Hotエンコーディングされた列を抽出して表示
df_train[["Gender","Gender_Female","Gender_Male"]]


### OneHotEncoderのインスタンスを作成し、sparse=Falseで密行列を指定
ohe_Geography=OneHotEncoder(sparse=False)

### OneHotEncoderを訓練データの"Gendet"列に適させる
ohe_Geography.fit(df_train[["Geography"]])

### OneHotエンコーディングされた特徴量を含むDataFrameを作成し、列名を指定
tmp_Geography = pd.DataFrame(
    ### OneHotエンコーディングを実行し、結果をDataFrameに保存
    ohe_Geography.transform(df_train[["Geography"]]),
    ### 列名設定
    columns=["Geography_{}".format(i) for i in ohe_Geography.categories_[0]],
)

### 元のデータフレームとOneHotエンコーディングされた特徴量を結合
df_train = pd.concat([df_train, tmp_Geography], axis=1)

### "Geography"列とOne-Hotエンコーディングされた列を抽出して表示
df_train[["Geography","Geography_France","Geography_Spain","Geography_Germany"]]
# Out:
#        Geography  Geography_France  Geography_Spain  Geography_Germany
# 0         France               1.0              0.0                0.0
# 1         France               1.0              0.0                0.0
# 2         France               1.0              0.0                0.0
# 3         France               1.0              0.0                0.0
# 4          Spain               0.0              1.0                0.0
# ...          ...               ...              ...                ...
# 165029     Spain               0.0              1.0                0.0
# 165030    France               1.0              0.0                0.0
# 165031    France               1.0              0.0                0.0
# 165032     Spain               0.0              1.0                0.0
# 165033    France               1.0              0.0                0.0
#
# [165034 rows x 4 columns]

# %%
#GenderがMaleでかつIsActiveMemberが1の場合を1、それ以外を0とする新しい特徴量を作成する
df_train['Gender_Male_and_Active'] = ((df_train['Gender'] == 'Male') & (df_train['IsActiveMember'] == 1)).astype(int)
df_train["Gender_Male_+_Active"] = df_train["Gender_Male"] + df_train["IsActiveMember"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df_train['Gender_Male_and_Active'] = ((df_train['Gender'] == 'Male') & (df_train['IsActiveMember'] == 1)).astype(int)
#       3 df_train["Gender_Male_+_Active"] = df_train["Gender_Male"] + df_train["IsActiveMember"]
#
# NameError: name 'df_train' is not defined

# %%
# count=encoding
# "Surname" 列の各値の出現回数を数え、その結果を辞書に変換し、変数 ce_Surname に代入します。
ce_Surname = df_train["Surname"].value_counts().to_dict()

# 出現回数の辞書を出力します。
print(ce_Surname)

# "Surname" 列の各値を、出現回数の辞書にマッピングし、新しい列 "Surname_ce" を作成します。
df_train["Surname_ce"] = df_train["Surname"].map(ce_Surname)

df_train[["Surname_ce"]]
# "Surname" 列と新しい "Surname_ce" 列を含む DataFrame の最初の数行を表示します。
df_train[["Surname", "Surname_ce"]].head()
# Out:
# {'Hsia': 2456, "T'ien": 2282, 'Hs?': 1611, 'Kao': 1577, 'Maclean': 1577, "Ts'ui": 1567, "P'eng": 1503, 'H?': 1420, 'Hsueh': 1306, 'Shih': 1251, "Ch'ang": 1229, "Ch'iu": 1199, 'Mazzanti': 1192, 'Tuan': 1164, 'Fanucci': 1139, 'Onyemauchechukwu': 1138, 'Tien': 1132, 'Smith': 1129, 'Nwankwo': 1117, 'Manna': 1024, 'Teng': 1008, 'Hsiung': 988, "Ch'ien": 974, 'Genovese': 962, 'Hsieh': 939, "T'ao": 906, "Ts'ai": 900, 'Trevisani': 894, 'Martin': 875, "T'ang": 859, 'Hsing': 853, 'Y?an': 846, 'Pirozzi': 814, 'Y?': 759, "K'ung": 754, "Ch'eng": 752, 'Walker': 744, 'Tsao': 740, 'Scott': 729, 'White': 727, 'Nwachinemelu': 726, 'Toscani': 723, "Ch'in": 722, 'Pinto': 717, 'Trevisano': 714, 'Brown': 713, 'Palerma': 708, 'L?': 694, 'Lucchesi': 689, 'Lo Duca': 687, 'Hsiao': 666, 'Ting': 663, 'Nwabugwu': 662, 'Ritchie': 645, 'Liao': 644, 'K?': 632, 'Lucciano': 627, 'Chukwudi': 615, 'Mazzi': 611, 'Chiu': 608, 'Tung': 604, 'Hao': 594, 'Lu': 592, 'Lai': 591, 'Lo': 589, 'Yeh': 584, 'Cremonesi': 581, 'Hsu': 580, 'Chiang': 553, 'Iadanza': 549, 'Yobanna': 538, 'Lucchese': 537, 'Pagnotto': 534, 'Lettiere': 526, 'Folliero': 526, "Ts'ao": 524, 'Zetticci': 509, 'Milanesi': 487, 'Macleod': 485, 'Nnachetam': 481, 'Shao': 481, 'Calabresi': 477, 'Nwachukwu': 472, 'Milne': 472, 'Onwuamaeze': 465, "Ch'en": 460, 'Mancini': 454, 'Baresi': 445, 'Genovesi': 443, "O'Donnell": 438, 'Pisano': 437, 'Clements': 425, 'Onyemere': 423, 'Ugochukwu': 416, 'Chukwuemeka': 415, 'Chukwufumnanya': 412, 'Chia': 412, 'Calabrese': 406, 'Nnaife': 402, 'Onyekachi': 400, 'Yobachi': 398, 'Onwumelu': 395, 'Chien': 389, 'Chidubem': 386, 'Milani': 381, 'Iloerika': 370, 'Hs?eh': 368, 'Fiorentini': 368, 'Nkemakolam': 366, 'Chukwualuka': 365, 'Eluemuno': 363, 'Fiorentino': 362, 'Zikoranachidimma': 355, 'Tsou': 353, 'Palermo': 352, 'Nucci': 352, 'Onyekaozulu': 347, 'Tseng': 346, 'Rizzo': 342, 'Chuang': 341, 'Yobachukwu': 340, 'Cattaneo': 335, 'Olisaemeka': 331, 'Pisani': 329, 'Uspenskaya': 327, 'Chu': 326, 'Chin': 324, 'Nnonso': 321, 'Iweobiegbunam': 319, 'Hargreaves': 319, 'Ndubueze': 316, 'McGregor': 315, 'Okechukwu': 313, 'Ku': 307, 'Li Fonti': 304, 'Okwudiliolisa': 300, "P'an": 300, 'Aksenov': 299, 'Goliwe': 298, 'McIntyre': 296, "O'Brien": 285, 'Nkemakonam': 281, 'Nnamdi': 280, 'Yefremova': 279, 'Fan': 278, 'Okeke': 278, 'Bellucci': 276, 'De Luca': 276, 'Ijendu': 275, 'Udegbulam': 270, 'Lombardo': 268, 'Milano': 266, 'Piazza': 265, 'Nnanna': 265, 'Nnamutaezinwa': 264, 'Niu': 264, 'Uspensky': 263, 'Chukwumaobim': 262, 'Okwudilichukwu': 261, 'Dickson': 258, 'Onyemachukwu': 258, 'Tsai': 253, 'Aitken': 253, 'Nkemdilim': 251, 'Nkemjika': 251, 'Onio': 251, 'Ibezimako': 247, 'Chiemenam': 246, 'Young': 245, 'Chukwujamuike': 243, 'Chidiebere': 240, 'Yermakova': 239, 'Sun': 234, 'Udinese': 230, 'Ukaegbunam': 230, 'Frolov': 228, 'Okwuadigbo': 227, 'Chukwukadibia': 224, 'Chiazagomekpere': 222, 'Watson': 221, 'Chibueze': 218, 'Sagese': 218, 'Chukwueloka': 217, 'Nwebube': 211, 'Chukwuebuka': 208, 'Onyekachukwu': 208, 'Obialo': 207, 'Wright': 207, 'Kuo': 206, 'DeRose': 205, 'Ejimofor': 204, 'Fomin': 204, 'Chinedum': 204, 'Chiawuotu': 201, 'Fang': 200, 'Ozerova': 196, 'Nkemdirim': 196, 'Nwokezuike': 194, 'McLean': 194, 'Obiajulu': 194, 'Trevisan': 194, 'Zito': 193, 'Biryukov': 193, 'Hughes': 192, 'Yudina': 192, 'Ma': 191, 'Udegbunam': 191, 'Chukwubuikem': 188, 'Kambinachi': 188, 'Nwora': 187, 'Ojiofor': 186, 'Uwaezuoke': 185, 'Lombardi': 184, 'Oluchukwu': 184, "O'Sullivan": 181, 'Dyer': 180, 'Chidozie': 180, 'Li': 178, 'Chidimma': 178, 'Onyeorulu': 177, 'Chibugo': 176, 'Okonkwo': 176, 'Udinesi': 175, 'Black': 174, "T'an": 174, 'Wang': 167, 'Onyemauchechi': 167, 'Johnson': 163, 'Yashina': 163, 'Chukwukere': 162, 'Tretiakova': 162, 'Ugochukwutubelum': 160, 'Frolova': 159, 'Johnstone': 159, 'Padovesi': 158, 'Yermakov': 158, 'Chidiegwu': 158, 'Wilson': 156, 'Chiekwugo': 156, 'Chinwendu': 156, 'Yefimova': 151, 'Olisanugo': 151, 'Chidumaga': 151, 'Houghton': 150, 'Obidimkpa': 150, 'Efremov': 150, 'Ngozichukwuka': ...
#           Surname  Surname_ce
# 0  Okwudilichukwu         261
# 1   Okwudiliolisa         300
# 2           Hsueh        1306
# 3             Kao        1577
# 4       Chiemenam         246

# %%
#数値変数×カテゴリ変数(平均値作成)
df_train["mean_Age_by_Surname"] = df_train.groupby("Surname")["Age"].transform("mean")

df_train[["Surname", "Age", "mean_Age_by_Surname"]].head()
# Out:
#           Surname   Age  mean_Age_by_Surname
# 0  Okwudilichukwu  33.0            39.708812
# 1   Okwudiliolisa  33.0            39.753333
# 2           Hsueh  40.0            38.189127
# 3             Kao  34.0            37.192771
# 4       Chiemenam  33.0            39.089431

# %%
#以下、数値変数とカテゴリ変数を組み合わせての特徴量エンジニアリング

df_train["std_Age_by_Surname"] = df_train.groupby("Surname")["Age"].transform("std")
df_train["sum_Age_by_Surname"] = df_train.groupby("Surname")["Age"].transform("sum")
df_train["max_Age_by_Surname"] = df_train.groupby("Surname")["Age"].transform("max")
df_train["min_Age_by_Surname"] = df_train.groupby("Surname")["Age"].transform("min")
df_train["Balance_-_NumOfProducts"] = df_train["Balance"] - df_train["NumOfProducts"]
df_train["NumOfProducts_+_Age"] = df_train["NumOfProducts"] + df_train["Age"]
df_train["NumOfProducts_-_Age"] = df_train["NumOfProducts"] - df_train["Age"]
df_train["NumOfProducts_*_Age"] = df_train["NumOfProducts"] * df_train["Age"]
df_train["NumOfProducts_/_Age"] = df_train["NumOfProducts"] / df_train["Age"]
df_train["NumOfProducts_*_CreditScore"] = df_train["NumOfProducts"] * df_train["CreditScore"]
df_train["NumOfProducts_/_CreditScore"] = df_train["NumOfProducts"] / df_train["CreditScore"]
df_train["Tenure_+_HasCrCard"] = df_train["Tenure"] + df_train["HasCrCard"]
df_train["Tenure_*_HasCrCard"] = df_train["Tenure"] * df_train["HasCrCard"]

# %% [markdown]
# #### データセット作成

# %%
x_train,y_train,id_train=df_train[["IsActiveMember","EstimatedSalary","CreditScore","Gender_Male","Age","Balance",
                                   "Geography_Germany",'Gender_Male_and_Active',"Gender_Male_+_Active","Surname","Surname_ce","mean_Age_by_Surname",
                                   "std_Age_by_Surname","sum_Age_by_Surname","max_Age_by_Surname","NumOfProducts","Balance_-_NumOfProducts",
                                   "NumOfProducts_+_Age","NumOfProducts_-_Age","NumOfProducts_*_Age","NumOfProducts_/_Age","NumOfProducts_*_CreditScore",
                                   "NumOfProducts_/_CreditScore","Tenure_+_HasCrCard","Tenure_*_HasCrCard"]],\
                        df_train[["Exited"]],\
                        df_train[["id"]]
print(x_train.shape, y_train.shape, id_train.shape)
# Out:
# (165034, 25) (165034, 1) (165034, 1)

# %%
# DataFrame x_train の各列に対してループを行う
for col in x_train.columns:
    # もし列のデータ型が文字列型であれば

    if x_train[col].dtype=="O":
        # その列のデータ型をカテゴリ型に変換する
        x_train[col] = x_train[col].astype("category")

# %% [markdown]
# #### optunaのインポート

# %%
pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-3.6.1-py3-none-any.whl (380 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 380.1/380.1 kB 6.1 MB/s eta 0:00:00
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.13.1-py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.4/233.4 kB 8.8 MB/s eta 0:00:00
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.8.2-py3-none-any.whl (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (24.0)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.30)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.4)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.1)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.3-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 kB 9.3 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.11.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (3.0.3)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.5)
# Installing collected packages: Mako, colorlog, alembic, optuna
# Successfully installed Mako-1.3.3 alembic-1.13.1 colorlog-6.8.2 optuna-3.6.1

# %%
import optuna

# %% [markdown]
# #### 目的関数の定義

# %%
# 探索しないハイパーパラメータ
params_base = {
    "boosting_type": "gbdt",
    "objective": "binary",
    "metric": "auc",
    "learning_rate": 0.02,
    'n_estimators': 100000,
    "bagging_freq": 1,
    "seed": 123,
}

def objective(trial):
    # 探索するハイパーパラメータ
    params_tuning = {
        "num_leaves": trial.suggest_int("num_leaves", 8, 256),
        "min_data_in_leaf": trial.suggest_int("min_data_in_leaf", 5, 200),
        "min_sum_hessian_in_leaf": trial.suggest_float("min_sum_hessian_in_leaf", 1e-5, 1e-2, log=True),
        "feature_fraction": trial.suggest_float("feature_fraction", 0.5, 1.0),
        "bagging_fraction": trial.suggest_float("bagging_fraction", 0.5, 1.0),
        "lambda_l1": trial.suggest_float("lambda_l1", 1e-2, 1e2, log=True),
        "lambda_l2": trial.suggest_float("lambda_l2", 1e-2, 1e2, log=True),
    }
    params_tuning.update(params_base)

    # モデル学習・評価
    list_metrics = []
    cv = list(StratifiedKFold(n_splits=5, shuffle=True, random_state=123).split(x_train, y_train))
    list_fold=[0,1,2]
    for nfold in list_fold:
        idx_tr, idx_va = cv[nfold][0], cv[nfold][1]
        x_tr, y_tr = x_train.loc[idx_tr, :], y_train.loc[idx_tr, :]
        x_va, y_va = x_train.loc[idx_va, :], y_train.loc[idx_va, :]
        model = lgb.LGBMClassifier(**params_tuning)
        model.fit(x_tr,
                  y_tr,
                  eval_set=[(x_tr,y_tr), (x_va,y_va)],
                  #early_stopping_rounds=100,
                  callbacks=[lgb.early_stopping(stopping_rounds=100, verbose=True),
                  lgb.log_evaluation()], # コマンドライン出力用コールバック関数　修正処理
                  #verbose=10,
                  eval_metric='auc',  # 早期停止の評価メトリックスを指定するのが良いです
                 )
        y_va_pred = model.predict_proba(x_va)[:,1]
        metric_va = roc_auc_score(y_va, y_va_pred)
        list_metrics.append(metric_va)

    # 評価値の計算
    metrics = np.mean(list_metrics)

    return metrics

# %% [markdown]
# #### 最適化処理（探索の実行）

# %%
# TPESamplerを使用してサンプラーオブジェクトを作成し、乱数のシードを指定
sampler = optuna.samplers.TPESampler(seed=123)

# サンプラーを指定してStudyオブジェクトを作成し、最大化方向を設定
study = optuna.create_study(sampler=sampler, direction="maximize")

# 目的関数を最適化してハイパーパラメータを探索（30回の試行）
study.optimize(objective, n_trials=30)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# #### 探索結果の確認

# %%
# Studyオブジェクトから最良のトライアル（試行）を取得し、trial変数に代入
trial = study.best_trial

# 最良のトライアルの評価値を表示し、小数点以下4桁まで表示
print("acc(best)={:.4f}".format(trial.value))

# 最良のトライアルで使用されたハイパーパラメータの値を表示
display(trial.params)
# Out:
# acc(best)=0.8952
# {'num_leaves': 32,
#  'min_data_in_leaf': 198,
#  'min_sum_hessian_in_leaf': 0.000911024108147967,
#  'feature_fraction': 0.5040305717020102,
#  'bagging_fraction': 0.9940542446575642,
#  'lambda_l1': 74.98841302101062,
#  'lambda_l2': 34.144257057990224}

# %% [markdown]
# #### ベストなハイパーパラメータの取得

# %%
# 最良のトライアルで使用されたハイパーパラメータを取得し、params_best変数に代入
params_best = trial.params

# ベースのハイパーパラメータと最良のトライアルで使用されたハイパーパラメータを結合
params_best.update(params_base)

# 結合されたハイパーパラメータの値を表示
display(params_best)
# Out:
# {'num_leaves': 32,
#  'min_data_in_leaf': 198,
#  'min_sum_hessian_in_leaf': 0.000911024108147967,
#  'feature_fraction': 0.5040305717020102,
#  'bagging_fraction': 0.9940542446575642,
#  'lambda_l1': 74.98841302101062,
#  'lambda_l2': 34.144257057990224,
#  'boosting_type': 'gbdt',
#  'objective': 'binary',
#  'metric': 'auc',
#  'learning_rate': 0.02,
#  'n_estimators': 100000,
#  'bagging_freq': 1,
#  'seed': 123}

# %%
params ={'num_leaves': 32,
 'min_data_in_leaf': 198,
 'min_sum_hessian_in_leaf': 0.000911024108147967,
 'feature_fraction': 0.5040305717020102,
 'bagging_fraction': 0.9940542446575642,
 'lambda_l1': 74.98841302101062,
 'lambda_l2': 34.144257057990224,
 'boosting_type': 'gbdt',
 'objective': 'binary',
 'metric': 'auc',
 'learning_rate': 0.02,
 'n_estimators': 100000,
 'bagging_freq': 1,
 'seed': 123}
def train_cv(input_x,
             input_y,
             input_id,
             params,
             n_splits=5,
            ):
    metrics = []
    imp = pd.DataFrame()

    cv = list(StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=123).split(input_x, input_y))
    for nfold in np.arange(n_splits):
        print("-"*20, nfold, "-"*20)
        idx_tr, idx_va = cv[nfold][0], cv[nfold][1]
        x_tr, y_tr = input_x.loc[idx_tr, :], input_y.loc[idx_tr, :]
        x_va, y_va = input_x.loc[idx_va, :], input_y.loc[idx_va, :]
        print(x_tr.shape, y_tr.shape)
        print(x_va.shape, y_va.shape)
        print("y_train:{:.3f}, y_tr:{:.3f}, y_va:{:.3f}".format(
            input_y["Exited"].mean(),
            y_tr["Exited"].mean(),
            y_va["Exited"].mean(),
        ))

        model = lgb.LGBMClassifier(**params)
        model.fit(x_tr,
                  y_tr,
                  eval_set=[(x_tr,y_tr), (x_va,y_va)],
                  #early_stopping_rounds=100,
                  callbacks=[lgb.early_stopping(stopping_rounds=100, verbose=True),
                  lgb.log_evaluation()], # コマンドライン出力用コールバック関数　修正処理
                  #verbose=10,
                  eval_metric='auc',  # 早期停止の評価メトリックスを指定するのが良いです
                  )


        y_tr_pred = model.predict_proba(x_tr)[:,1]
        y_va_pred = model.predict_proba(x_va)[:,1]
        metric_tr = roc_auc_score(y_tr, y_tr_pred)
        metric_va = roc_auc_score(y_va, y_va_pred)
        print("[accuracy] tr: {:.2f}, va: {:.2f}".format(metric_tr, metric_va))
        metrics.append([nfold, metric_tr, metric_va])

        _imp = pd.DataFrame({"col":input_x.columns, "imp":model.feature_importances_, "nfold":nfold})
        imp = pd.concat([imp, _imp], axis=0, ignore_index=True)

    print("-"*20, "result", "-"*20)
    metrics = np.array(metrics)
    print(metrics)

    print("[cv ] tr: {:.2f}+-{:.2f}, va: {:.2f}+-{:.2f}".format(
        metrics[:,1].mean(), metrics[:,1].std(),
        metrics[:,2].mean(), metrics[:,2].std(),
    ))

    imp = imp.groupby("col")["imp"].agg(["mean", "std"])
    imp.columns = ["imp", "imp_std"]
    imp = imp.reset_index(drop=False)

    print("Done.")

    return imp, metrics

# %%
#ベストなハイパーパラメータの取得後のモデル学習
imp, metrics = train_cv(x_train, y_train, id_train, params, n_splits=5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 imp, metrics = train_cv(x_train, y_train, id_train, params, n_splits=5)
#
# NameError: name 'train_cv' is not defined

# %%
#推論用データセット、特徴量エンジニアリング

df_test = pd.read_csv("Bank Churn/test.csv")

### OneHotEncoderのインスタンスを作成し、sparse=Falseで密行列を指定
ohe_Gender=OneHotEncoder(sparse=False)


### OneHotEncoderを訓練データの"Gender"列に適させる

ohe_Gender.fit(df_test[["Gender"]])

### OneHotエンコーディングされた特徴量を含むDataFrameを作成し、列名を指定
tmp_Gender = pd.DataFrame(
    ### OneHotエンコーディングを実行し、結果をDataFrameに保存
    ohe_Gender.transform(df_test[["Gender"]]),
    ### 列名設定
    columns=["Gender_{}".format(i) for i in ohe_Gender.categories_[0]],
)


### 元のデータフレームとOneHotエンコーディングされた特徴量を結合
df_test = pd.concat([df_test, tmp_Gender], axis=1)
### "Gender"列とOne-Hotエンコーディングされた列を抽出して表示
df_test[["Gender","Gender_Female","Gender_Male"]]



### OneHotEncoderのインスタンスを作成し、sparse=Falseで密行列を指定
ohe_Geography=OneHotEncoder(sparse=False)

### OneHotEncoderを訓練データの"Gendet"列に適させる
ohe_Geography.fit(df_train[["Geography"]])

### OneHotエンコーディングされた特徴量を含むDataFrameを作成し、列名を指定
tmp_Geography = pd.DataFrame(
    ### OneHotエンコーディングを実行し、結果をDataFrameに保存
    ohe_Geography.transform(df_test[["Geography"]]),
    ### 列名を "Embarked_0", "Embarked_1" などに設定
    columns=["Geography_{}".format(i) for i in ohe_Geography.categories_[0]],
)

### 元のデータフレームとOneHotエンコーディングされた特徴量を結合
df_test = pd.concat([df_test, tmp_Geography], axis=1)

### "Geography"列とOne-Hotエンコーディングされた列を抽出して表示
df_test[["Geography","Geography_France","Geography_Spain","Geography_Germany"]]


df_test['Gender_Male_and_Active'] = ((df_test['Gender'] == 'Male') & (df_test['IsActiveMember'] == 1)).astype(int)



df_test["Gender_Male_+_Active"] = df_test["Gender_Male"] + df_test["IsActiveMember"]

# "Surname" 列の各値の出現回数を数え、その結果を辞書に変換し、変数 ce_Surname に代入します。
ce_Surname = df_test["Surname"].value_counts().to_dict()

# 出現回数の辞書を出力します。
print(ce_Surname)

# "Surname" 列の各値を、出現回数の辞書にマッピングし、新しい列 "Surname_ce" を作成します。
df_test["Surname_ce"] = df_test["Surname"].map(ce_Surname)

df_test[["Surname_ce"]]
# "Surname" 列と新しい "Surname_ce" 列を含む DataFrame の最初の数行を表示します。
df_test[["Surname", "Surname_ce"]].head()

df_test["mean_Age_by_Surname"] = df_test.groupby("Surname")["Age"].transform("mean")

df_test["std_Age_by_Surname"] = df_test.groupby("Surname")["Age"].transform("std")
df_test["sum_Age_by_Surname"] = df_test.groupby("Surname")["Age"].transform("sum")
df_test["max_Age_by_Surname"] = df_test.groupby("Surname")["Age"].transform("max")
df_test["min_Age_by_Surname"] = df_test.groupby("Surname")["Age"].transform("min")
df_test["Balance_-_NumOfProducts"] = df_test["Balance"] - df_test["NumOfProducts"]


df_test["NumOfProducts_+_Age"] = df_test["NumOfProducts"] + df_test["Age"]
df_test["NumOfProducts_-_Age"] = df_test["NumOfProducts"] - df_test["Age"]
df_test["NumOfProducts_*_Age"] = df_test["NumOfProducts"] * df_test["Age"]
df_test["NumOfProducts_/_Age"] = df_test["NumOfProducts"] / df_test["Age"]

df_test["NumOfProducts_*_CreditScore"] = df_test["NumOfProducts"] * df_test["CreditScore"]
df_test["NumOfProducts_/_CreditScore"] = df_test["NumOfProducts"] / df_test["CreditScore"]
df_test["Tenure_+_HasCrCard"] = df_test["Tenure"] + df_test["HasCrCard"]
df_test["Tenure_*_HasCrCard"] = df_test["Tenure"] * df_test["HasCrCard"]



x_test = df_test[["IsActiveMember","EstimatedSalary","CreditScore","Gender_Male","Age","Balance",
                                   "Geography_Germany",'Gender_Male_and_Active',"Gender_Male_+_Active","Surname","Surname_ce","mean_Age_by_Surname",
                                   "std_Age_by_Surname","sum_Age_by_Surname","max_Age_by_Surname","NumOfProducts","Balance_-_NumOfProducts",
                  "NumOfProducts_+_Age","NumOfProducts_-_Age","NumOfProducts_*_Age","NumOfProducts_/_Age","NumOfProducts_*_CreditScore",
                  "NumOfProducts_/_CreditScore","Tenure_+_HasCrCard","Tenure_*_HasCrCard"]]
id_test = df_test[["id"]]
# Out:
# {'Hsia': 1606, "T'ien": 1484, 'Hs?': 1124, 'Maclean': 1042, "Ts'ui": 1017, 'Kao': 1000, "P'eng": 954, 'H?': 944, 'Hsueh': 872, 'Mazzanti': 860, "Ch'iu": 857, 'Tuan': 819, 'Nwankwo': 810, 'Shih': 793, "Ch'ang": 792, 'Smith': 775, 'Onyemauchechukwu': 769, 'Fanucci': 735, 'Tien': 728, "Ch'ien": 697, 'Manna': 687, 'Trevisani': 678, 'Hsiung': 673, 'Genovese': 649, 'Hsieh': 643, 'Teng': 614, "Ts'ai": 590, 'Hsing': 584, "T'ang": 578, "T'ao": 576, 'Pirozzi': 562, 'Y?': 553, 'Y?an': 545, "K'ung": 534, "Ch'eng": 520, 'Scott': 516, 'Toscani': 512, 'Tsao': 508, 'Hsiao': 504, 'Walker': 499, 'Nwachinemelu': 485, 'White': 483, 'Martin': 482, 'Pinto': 479, "Ch'in": 478, 'Trevisano': 477, 'Palerma': 477, 'Brown': 470, 'Liao': 461, 'Nwabugwu': 456, 'K?': 452, 'Lucchesi': 445, 'Lo Duca': 443, 'Ting': 442, 'Lucciano': 442, 'Lu': 439, 'Lo': 437, 'L?': 433, 'Mazzi': 421, 'Tung': 419, 'Ritchie': 412, 'Lai': 411, 'Lucchese': 403, 'Chukwudi': 400, 'Chiu': 394, 'Folliero': 383, 'Cremonesi': 382, 'Lettiere': 379, 'Pagnotto': 367, "Ts'ao": 364, 'Chiang': 361, 'Yeh': 356, 'Hao': 356, 'Macleod': 354, 'Hsu': 354, "Ch'en": 348, 'Yobanna': 347, 'Shao': 344, 'Onyemere': 335, 'Milanesi': 330, 'Zetticci': 327, 'Iadanza': 324, 'Nwachukwu': 321, 'Clements': 302, "O'Donnell": 301, 'Onwuamaeze': 300, 'Baresi': 300, 'Calabresi': 299, 'Mancini': 298, 'Nnachetam': 297, 'Milne': 292, 'Calabrese': 289, 'Chia': 287, 'Pisano': 284, 'Genovesi': 284, 'Chukwufumnanya': 278, 'Onwumelu': 273, 'Milani': 270, 'Yobachi': 269, 'Onyekachi': 263, 'Tsou': 261, 'Chukwuemeka': 259, 'Nnaife': 257, 'Nucci': 255, 'Fiorentino': 250, 'Chu': 248, 'Cattaneo': 248, 'Ugochukwu': 246, 'Hs?eh': 244, 'Palermo': 244, 'Zikoranachidimma': 243, 'Ndubueze': 242, 'Uspenskaya': 242, 'Chidubem': 241, 'Onyekaozulu': 240, 'Okwudiliolisa': 239, 'Nkemakolam': 235, 'Rizzo': 234, 'Pisani': 232, 'Fiorentini': 229, 'Eluemuno': 228, 'Iloerika': 228, 'Chuang': 227, 'McGregor': 227, 'Yobachukwu': 226, 'Chukwualuka': 225, 'Okechukwu': 225, 'Chien': 216, 'Yefremova': 209, 'Olisaemeka': 208, 'Tseng': 208, 'Li Fonti': 201, 'Okeke': 200, 'Chukwumaobim': 194, 'Ku': 194, 'Uspensky': 192, 'Iweobiegbunam': 190, 'Ijendu': 189, 'Nnonso': 188, 'Aksenov': 187, 'Hargreaves': 187, 'McIntyre': 186, 'Nkemakonam': 185, "O'Brien": 185, 'Niu': 183, 'Nkemjika': 183, 'Fan': 183, 'Udegbulam': 181, 'Chin': 180, 'Okwudilichukwu': 178, 'Onio': 178, 'Nnamdi': 175, 'Goliwe': 173, 'Onyemachukwu': 173, 'Chukwujamuike': 173, 'De Luca': 170, 'Nnamutaezinwa': 169, "P'an": 167, 'Udinese': 167, 'Ejimofor': 166, 'Nwora': 166, 'Bellucci': 163, 'Milano': 162, 'Dickson': 162, 'Tsai': 161, 'Aitken': 160, 'Chukwueloka': 160, 'Yermakova': 159, 'Obialo': 159, 'Watson': 159, 'Chidiebere': 158, 'Chukwukadibia': 156, 'Nnanna': 154, 'Nkemdilim': 154, 'Lombardo': 150, 'Piazza': 150, 'Frolov': 149, 'Ma': 149, 'Okwuadigbo': 147, 'Kuo': 146, 'Ozerova': 145, 'Nwebube': 142, 'Yermakov': 142, 'Chinedum': 142, 'Nkemdirim': 141, 'Sagese': 141, 'Zito': 141, 'Biryukov': 140, 'Sun': 139, 'Hughes': 139, "O'Sullivan": 138, 'Onyekachukwu': 137, 'Ibezimako': 136, 'Chiazagomekpere': 136, 'Chukwuebuka': 133, 'Udegbunam': 133, 'Chiemenam': 133, 'Tretiakova': 132, 'Young': 131, 'Chidozie': 131, 'Oluchukwu': 131, 'Yudina': 130, 'Fomin': 129, 'Obiajulu': 128, 'Fang': 128, 'Onyemauchechi': 128, 'DeRose': 128, 'Chibueze': 128, 'Kambinachi': 127, 'Nwokezuike': 127, 'Udinesi': 127, 'Li': 126, 'Dyer': 124, 'Uwaezuoke': 123, 'Ukaegbunam': 123, "T'an": 122, 'Wright': 122, 'Galkin': 120, 'Yefimova': 120, 'Houghton': 120, 'Chukwukere': 118, 'Chukwubuikem': 118, 'Okonkwo': 117, 'Johnson': 116, 'Ngozichukwuka': 114, 'Chidimma': 114, 'Chiekwugo': 114, 'Chibugo': 114, 'Chiawuotu': 113, 'Lin': 112, 'Chidiegwu': 112, 'Lombardi': 112, 'McLean': 111, 'Chigozie': 111, 'Uvarova': 110, 'Johnstone': 109, 'Chidumaga': 109, 'Olisanugo': 107, 'Chinomso': 106, 'Chikezie': 106, 'Thompson': 106, 'Yashina': 106, 'Padovesi': 105, 'Ugochukwutubelum': 105, 'Moore': 104, 'Efremov': 104, 'Wang': 103, 'Wilson': 102, ' ...

# %%
# DataFrame x_test の各列に対してループを行う
for col in x_test.columns:
    # もし列のデータ型が文字列型であれば

    if x_test[col].dtype=="O":
        # その列のデータ型をカテゴリ型に変換する
        x_test[col] = x_test[col].astype("category")

# %% [markdown]
# モデル学習・評価（推論用データセット作成後）

# %%
params ={'num_leaves': 32,
 'min_data_in_leaf': 198,
 'min_sum_hessian_in_leaf': 0.000911024108147967,
 'feature_fraction': 0.5040305717020102,
 'bagging_fraction': 0.9940542446575642,
 'lambda_l1': 74.98841302101062,
 'lambda_l2': 34.144257057990224,
 'boosting_type': 'gbdt',
 'objective': 'binary',
 'metric': 'auc',
 'learning_rate': 0.02,
 'n_estimators': 100000,
 'bagging_freq': 1,
 'seed': 123}

def predict_lgb(input_x,
             input_y,
             input_id,
             params,
             n_splits=5,
            ):
    metrics = []
    imp = pd.DataFrame()

    cv = list(StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=123).split(input_x, input_y))
    for nfold in np.arange(n_splits):
        print("-"*20, nfold, "-"*20)
        idx_tr, idx_va = cv[nfold][0], cv[nfold][1]
        x_tr, y_tr = input_x.loc[idx_tr, :], input_y.loc[idx_tr, :]
        x_va, y_va = input_x.loc[idx_va, :], input_y.loc[idx_va, :]
        print(x_tr.shape, y_tr.shape)
        print(x_va.shape, y_va.shape)
        print("y_train:{:.3f}, y_tr:{:.3f}, y_va:{:.3f}".format(
            input_y["Exited"].mean(),
            y_tr["Exited"].mean(),
            y_va["Exited"].mean(),
        ))

        model = lgb.LGBMClassifier(**params)
        model.fit(x_tr,
                  y_tr,
                  eval_set=[(x_tr,y_tr), (x_va,y_va)],
                  #early_stopping_rounds=100,
                  callbacks=[lgb.early_stopping(stopping_rounds=100, verbose=True),
                  lgb.log_evaluation()], # コマンドライン出力用コールバック関数　修正処理
                  #verbose=10,
                  eval_metric='auc',  # 早期停止の評価メトリックスを指定するのが良いです
                  )


        y_tr_pred = model.predict_proba(x_tr)[:,1]
        y_va_pred = model.predict_proba(x_va)[:,1]
        metric_tr = roc_auc_score(y_tr, y_tr_pred)
        metric_va = roc_auc_score(y_va, y_va_pred)
        print("[accuracy] tr: {:.2f}, va: {:.2f}".format(metric_tr, metric_va))
        metrics.append([nfold, metric_tr, metric_va])

        _imp = pd.DataFrame({"col":input_x.columns, "imp":model.feature_importances_, "nfold":nfold})
        imp = pd.concat([imp, _imp], axis=0, ignore_index=True)

    print("-"*20, "result", "-"*20)
    metrics = np.array(metrics)
    print(metrics)

    print("[cv ] tr: {:.2f}+-{:.2f}, va: {:.2f}+-{:.2f}".format(
        metrics[:,1].mean(), metrics[:,1].std(),
        metrics[:,2].mean(), metrics[:,2].std(),
    ))

    imp = imp.groupby("col")["imp"].agg(["mean", "std"])
    imp.columns = ["imp", "imp_std"]
    imp = imp.reset_index(drop=False)

    print("Done.")

    return model,imp, metrics

# %%
#モデル学習・評価（推論用データセット作成後）
model,imp, metrics = predict_lgb(x_train, y_train, id_train, params, n_splits=5)
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
# [291]	training's auc: 0.904184	valid_1's auc: 0.892063
# [292]	training's auc: 0.904185	valid_1's auc: 0.892066
# [293]	training's auc: 0.904235	valid_1's auc: 0.892078
# [294]	training's auc: 0.904293	valid_1's auc: 0.892092
# [295]	training's auc: 0.904302	valid_1's auc: 0.892099
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [296]	training's auc: 0.90431	valid_1's auc: 0.892104
# [297]	training's auc: 0.904358	valid_1's auc: 0.892114
# [298]	training's auc: 0.904369	valid_1's auc: 0.892122
# [299]	training's auc: 0.904379	valid_1's auc: 0.892138
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [300]	training's auc: 0.904384	valid_1's auc: 0.892142
# [301]	training's auc: 0.904398	valid_1's auc: 0.89215
# [302]	training's auc: 0.904451	valid_1's auc: 0.892164
# [303]	training's auc: 0.904494	valid_1's auc: 0.892165
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [304]	training's auc: 0.9045	valid_1's auc: 0.892169
# [305]	training's auc: 0.904541	valid_1's auc: 0.892181
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [306]	training's auc: 0.904546	valid_1's auc: 0.892187
# [307]	training's auc: 0.904589	valid_1's auc: 0.892198
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [308]	training's auc: 0.904594	valid_1's auc: 0.892201
# [309]	training's auc: 0.904639	valid_1's auc: 0.892216
# [310]	training's auc: 0.904651	valid_1's auc: 0.892231
# [311]	training's auc: 0.904697	valid_1's auc: 0.892245
# [312]	training's auc: 0.904749	valid_1's auc: 0.892261
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [313]	training's auc: 0.904758	valid_1's auc: 0.892267
# [314]	training's auc: 0.904792	valid_1's auc: 0.892276
# [315]	training's auc: 0.904836	valid_1's auc: 0.892282
# [316]	training's auc: 0.904875	valid_1's auc: 0.892292
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [317]	training's auc: 0.90488	valid_1's auc: 0.892297
# [318]	training's auc: 0.904918	valid_1's auc: 0.892304
# [319]	training's auc: 0.90496	valid_1's auc: 0.892323
# [320]	training's auc: 0.904972	valid_1's auc: 0.89233
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [321]	training's auc: 0.904977	valid_1's auc: 0.892334
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [322]	training's auc: 0.904983	valid_1's auc: 0.892339
# [323]	training's auc: 0.905021	valid_1's auc: 0.892346
# [324]	training's auc: 0.905032	valid_1's auc: 0.892351
# [325]	training's auc: 0.905074	valid_1's auc: 0.892355
# [326]	training's auc: 0.905109	valid_1's auc: 0.892362
# [327]	training's auc: 0.90516	valid_1's auc: 0.89237
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [328]	training's auc: 0.905163	valid_1's auc: 0.892374
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [329]	training's auc: 0.90517	valid_1's auc: 0.89238
# [330]	training's auc: 0.905216	valid_1's auc: 0.892387
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [331]	training's auc: 0.90522	valid_1's auc: 0.892395
# [332]	training's auc: 0.90526	valid_1's auc: 0.892402
# [333]	training's auc: 0.905313	valid_1's auc: 0.892419
# [334]	training's auc: 0.905322	valid_1's auc: 0.892433
# [335]	training's auc: 0.905373	valid_1's auc: 0.892446
# [336]	training's auc: 0.905379	valid_1's auc: 0.892449
# [337]	training's auc: 0.905428	valid_1's auc: 0.892458
# [338]	training's auc: 0.905468	valid_1's auc: 0.892456
# [339]	training's auc: 0.905503	valid_1's auc: 0.892458
# [340]	training's auc: 0.905541	valid_1's auc: 0.892466
# [341]	training's auc: 0.905575	valid_1's auc: 0.892471
# [342]	training's auc: 0.905621	valid_1's auc: 0.892476
# [343]	training's auc: 0.905659	valid_1's auc: 0.892479
# [344]	training's auc: 0.905707	valid_1's auc: 0.892486
# [345]	training's auc: 0.90575	valid_1's auc: 0.892497
# [346]	training's auc: 0.90576	valid_1's auc: 0.892503
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [347]	training's auc: 0.905764	valid_1's auc: 0.892504
# [348]	training's auc: 0.905774	valid_1's auc: 0.892517
# [349]	training's auc: 0.905813	valid_1's auc: 0.892522
# [350]	training's auc: 0.90586	valid_1's auc: 0.892534
# [351]	training's auc: 0.905897	valid_1's auc: 0.892535
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [352]	training's auc: 0.905902	valid_1's auc: 0.892539
# [353]	training's auc: 0.90594	valid_1's auc: 0.892539
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [354]	training's auc: 0.90595	valid_1's auc: 0.89255
# [355]	training's auc: 0.905989	valid_1's auc: 0.892557
# [356]	training's auc: 0.906	valid_1's auc: 0.892569
# [357]	training's auc: 0.906041	valid_1's auc: 0.892574
# [358]	training's auc: 0.906071	valid_1's auc: 0.892581
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [359]	training's auc: 0.906073	valid_1's auc: 0.892584
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [360]	training's auc: 0.906078	valid_1's auc: 0.892593
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [361]	training's auc: 0.906083	valid_1's auc: 0.892596
# [362]	training's auc: 0.906092	valid_1's auc: 0.8926
# [363]	training's auc: 0.906122	valid_1's auc: 0.892596
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [364]	training's auc: 0.906124	valid_1's auc: 0.892598
# [365]	training's auc: 0.90613	valid_1's auc: 0.892603
# [366]	training's auc: 0.906167	valid_1's auc: 0.892607
# [367]	training's auc: 0.906205	valid_1's auc: 0.892614
# [368]	training's auc: 0.906213	valid_1's auc: 0.892617
# [369]	training's auc: 0.906247	valid_1's auc: 0.892627
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [370]	training's auc: 0.906251	valid_1's auc: 0.89263
# [371]	training's auc: 0.906294	valid_1's auc: 0.892637
# [372]	training's auc: 0.906302	valid_1's auc: 0.89264
# [373]	training's auc: 0.906309	valid_1's auc: 0.892643
# [374]	training's auc: 0.906338	valid_1's auc: 0.892653
# [375]	training's auc: 0.906343	valid_1's auc: 0.89266
# [376]	training's auc: 0.906383	valid_1's auc: 0.892662
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [377]	training's auc: 0.906387	valid_1's auc: 0.892664
# [378]	training's auc: 0.90642	valid_1's auc: 0.892666
# [379]	training's auc: 0.906428	valid_1's auc: 0.892669
# [380]	training's auc: 0.906459	valid_1's auc: 0.892681
# [381]	training's auc: 0.906496	valid_1's auc: 0.892683
# [382]	training's auc: 0.906529	valid_1's auc: 0.892689
# [383]	training's auc: 0.906553	valid_1's auc: 0.892684
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [384]	training's auc: 0.906558	valid_1's auc: 0.892687
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [385]	training's auc: 0.906562	valid_1's auc: 0.892693
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [386]	training's auc: 0.906572	valid_1's auc: 0.892704
# [387]	training's auc: 0.906576	valid_1's auc: 0.892709
# [388]	training's auc: 0.906586	valid_1's auc: 0.892725
# [389]	training's auc: 0.906592	valid_1's auc: 0.892729
# [390]	training's auc: 0.906624	valid_1's auc: 0.892734
# [391]	training's auc: 0.906652	valid_1's auc: 0.892731
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [392]	training's auc: 0.906658	valid_1's auc: 0.892737
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [393]	training's auc: 0.906662	valid_1's auc: 0.892737
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [394]	training's auc: 0.906668	valid_1's auc: 0.892743
# [395]	training's auc: 0.906704	valid_1's auc: 0.892751
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [396]	training's auc: 0.90671	valid_1's auc: 0.892755
# [397]	training's auc: 0.906716	valid_1's auc: 0.892757
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [398]	training's auc: 0.906721	valid_1's auc: 0.892759
# [399]	training's auc: 0.906748	valid_1's auc: 0.892768
# [400]	training's auc: 0.90678	valid_1's auc: 0.892771
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [401]	training's auc: 0.906786	valid_1's auc: 0.892777
# [402]	training's auc: 0.906826	valid_1's auc: 0.892781
# [403]	training's auc: 0.906832	valid_1's auc: 0.892788
# [404]	training's auc: 0.90686	valid_1's auc: 0.892795
# [405]	training's auc: 0.906894	valid_1's auc: 0.892802
# [406]	training's auc: 0.906926	valid_1's auc: 0.892807
# [407]	training's auc: 0.906961	valid_1's auc: 0.892813
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [408]	training's auc: 0.906964	valid_1's auc: 0.892812
# [409]	training's auc: 0.906988	valid_1's auc: 0.892813
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [410]	training's auc: 0.906995	valid_1's auc: 0.892826
# [411]	training's auc: 0.907024	valid_1's auc: 0.892824
# [412]	training's auc: 0.907057	valid_1's auc: 0.892832
# [413]	training's auc: 0.907089	valid_1's auc: 0.89284
# [414]	training's auc: 0.907128	valid_1's auc: 0.89284
# [415]	training's auc: 0.907134	valid_1's auc: 0.892846
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [416]	training's auc: 0.907141	valid_1's auc: 0.892853
# [417]	training's auc: 0.907166	valid_1's auc: 0.892846
# [418]	training's auc: 0.907173	valid_1's auc: 0.892858
# [419]	training's auc: 0.907207	valid_1's auc: 0.892863
# [420]	training's auc: 0.907235	valid_1's auc: 0.892866
# [421]	training's auc: 0.907265	valid_1's auc: 0.892863
# [422]	training's auc: 0.907297	valid_1's auc: 0.892868
# [423]	training's auc: 0.907323	valid_1's auc: 0.892875
# [424]	training's auc: 0.907353	valid_1's auc: 0.892875
# [425]	training's auc: 0.907381	valid_1's auc: 0.892883
# [426]	training's auc: 0.907413	valid_1's auc: 0.892884
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [427]	training's auc: 0.907414	valid_1's auc: 0.892884
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [428]	training's auc: 0.907416	valid_1's auc: 0.892886
# [429]	training's auc: 0.907455	valid_1's auc: 0.892888
# [430]	training's auc: 0.907461	valid_1's auc: 0.892896
# [431]	training's auc: 0.907485	valid_1's auc: 0.892904
# [432]	training's auc: 0.907518	valid_1's auc: 0.892905
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [433]	training's auc: 0.907524	valid_1's auc: 0.892907
# [434]	training's auc: 0.90755	valid_1's auc: 0.892915
# [435]	training's auc: 0.907555	valid_1's auc: 0.892925
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [436]	training's auc: 0.907557	valid_1's auc: 0.892927
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [437]	training's auc: 0.907561	valid_1's auc: 0.89293
# [438]	training's auc: 0.907594	valid_1's auc: 0.892929
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [439]	training's auc: 0.907599	valid_1's auc: 0.892932
# [440]	training's auc: 0.907624	valid_1's auc: 0.892938
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [441]	training's auc: 0.907628	valid_1's auc: 0.892939
# [442]	training's auc: 0.907654	valid_1's auc: 0.892937
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [443]	training's auc: 0.90766	valid_1's auc: 0.892939
# [444]	training's auc: 0.907688	valid_1's auc: 0.892943
# [445]	training's auc: 0.907695	valid_1's auc: 0.89295
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [446]	training's auc: 0.907698	valid_1's auc: 0.892954
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [447]	training's auc: 0.907701	valid_1's auc: 0.892955
# [448]	training's auc: 0.907729	valid_1's auc: 0.892954
# [449]	training's auc: 0.907754	valid_1's auc: 0.892948
# [450]	training's auc: 0.907785	valid_1's auc: 0.892944
# [451]	training's auc: 0.907789	valid_1's auc: 0.892951
# [452]	training's auc: 0.907795	valid_1's auc: 0.892959
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [453]	training's auc: 0.9078	valid_1's auc: 0.892967
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [454]	training's auc: 0.907802	valid_1's auc: 0.892969
# [455]	training's auc: 0.907807	valid_1's auc: 0.892975
# [456]	training's auc: 0.907829	valid_1's auc: 0.892973
# [457]	training's auc: 0.907856	valid_1's auc: 0.892979
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [458]	training's auc: 0.90786	valid_1's auc: 0.892984
# [459]	training's auc: 0.907888	valid_1's auc: 0.892986
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [460]	training's auc: 0.907891	valid_1's auc: 0.892987
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [461]	training's auc: 0.907895	valid_1's auc: 0.892991
# [462]	training's auc: 0.907923	valid_1's auc: 0.892998
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [463]	training's auc: 0.907924	valid_1's auc: 0.892999
# [464]	training's auc: 0.907946	valid_1's auc: 0.893003
# [465]	training's auc: 0.907966	valid_1's auc: 0.892998
# [466]	training's auc: 0.907988	valid_1's auc: 0.893001
# [467]	training's auc: 0.907991	valid_1's auc: 0.893007
# [468]	training's auc: 0.908015	valid_1's auc: 0.893011
# [469]	training's auc: 0.908021	valid_1's auc: 0.893013
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [470]	training's auc: 0.908024	valid_1's auc: 0.893019
# [471]	training's auc: 0.90803	valid_1's auc: 0.893024
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [472]	training's auc: 0.908031	valid_1's auc: 0.893024
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [473]	training's auc: 0.908035	valid_1's auc: 0.893031
# [474]	training's auc: 0.908057	valid_1's auc: 0.893033
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [475]	training's auc: 0.90806	valid_1's auc: 0.893033
# [476]	training's auc: 0.908088	valid_1's auc: 0.893044
# [477]	training's auc: 0.908109	valid_1's auc: 0.89305
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [478]	training's auc: 0.908115	valid_1's auc: 0.893055
# [479]	training's auc: 0.908138	valid_1's auc: 0.893055
# [480]	training's auc: 0.908164	valid_1's auc: 0.893058
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [481]	training's auc: 0.908168	valid_1's auc: 0.89306
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [482]	training's auc: 0.908173	valid_1's auc: 0.893064
# [483]	training's auc: 0.908202	valid_1's auc: 0.893064
# [484]	training's auc: 0.908225	valid_1's auc: 0.893071
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [485]	training's auc: 0.908226	valid_1's auc: 0.893074
# [486]	training's auc: 0.908245	valid_1's auc: 0.893073
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [487]	training's auc: 0.908248	valid_1's auc: 0.893076
# [488]	training's auc: 0.908267	valid_1's auc: 0.893082
# [489]	training's auc: 0.908295	valid_1's auc: 0.893081
# [490]	training's auc: 0.90832	valid_1's auc: 0.893085
# [491]	training's auc: 0.908343	valid_1's auc: 0.893079
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [492]	training's auc: 0.908347	valid_1's auc: 0.893081
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [493]	training's auc: 0.908349	valid_1's auc: 0.893084
# [494]	training's auc: 0.908378	valid_1's auc: 0.893082
# [495]	training's auc: 0.908403	valid_1's auc: 0.893083
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [496]	training's auc: 0.908406	valid_1's auc: 0.893084
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [497]	training's auc: 0.908408	valid_1's auc: 0.893085
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [498]	training's auc: 0.90841	valid_1's auc: 0.893086
# [499]	training's auc: 0.908426	valid_1's auc: 0.893084
# [500]	training's auc: 0.908445	valid_1's auc: 0.893085
# [501]	training's auc: 0.908461	valid_1's auc: 0.893087
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [502]	training's auc: 0.908465	valid_1's auc: 0.89309
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [503]	training's auc: 0.908468	valid_1's auc: 0.893091
# [504]	training's auc: 0.908486	valid_1's auc: 0.893092
# [505]	training's auc: 0.908517	valid_1's auc: 0.8931
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [506]	training's auc: 0.908519	valid_1's auc: 0.893102
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [507]	training's auc: 0.908521	valid_1's auc: 0.893102
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [508]	training's auc: 0.908523	valid_1's auc: 0.893105
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [509]	training's auc: 0.908526	valid_1's auc: 0.893105
# [510]	training's auc: 0.908547	valid_1's auc: 0.893102
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [511]	training's auc: 0.908552	valid_1's auc: 0.893106
# [512]	training's auc: 0.908578	valid_1's auc: 0.893109
# [513]	training's auc: 0.908599	valid_1's auc: 0.893103
# [514]	training's auc: 0.908633	valid_1's auc: 0.893109
# [515]	training's auc: 0.908658	valid_1's auc: 0.89311
# [516]	training's auc: 0.908682	valid_1's auc: 0.893116
# [517]	training's auc: 0.908699	valid_1's auc: 0.893117
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [518]	training's auc: 0.908702	valid_1's auc: 0.893118
# [519]	training's auc: 0.908705	valid_1's auc: 0.893121
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [520]	training's auc: 0.908706	valid_1's auc: 0.893122
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [521]	training's auc: 0.908709	valid_1's auc: 0.893123
# [522]	training's auc: 0.908748	valid_1's auc: 0.893129
# [523]	training's auc: 0.908753	valid_1's auc: 0.893136
# [524]	training's auc: 0.908773	valid_1's auc: 0.893131
# [525]	training's auc: 0.908794	valid_1's auc: 0.893131
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [526]	training's auc: 0.908796	valid_1's auc: 0.893132
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [527]	training's auc: 0.908797	valid_1's auc: 0.893133
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [528]	training's auc: 0.9088	valid_1's auc: 0.893133
# [529]	training's auc: 0.908828	valid_1's auc: 0.893138
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [530]	training's auc: 0.90883	valid_1's auc: 0.893142
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [531]	training's auc: 0.908834	valid_1's auc: 0.893145
# [532]	training's auc: 0.908849	valid_1's auc: 0.893147
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [533]	training's auc: 0.90885	valid_1's auc: 0.893148
# [534]	training's auc: 0.908869	valid_1's auc: 0.89315
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [535]	training's auc: 0.908871	valid_1's auc: 0.893152
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [536]	training's auc: 0.908873	valid_1's auc: 0.893154
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [537]	training's auc: 0.908875	valid_1's auc: 0.893155
# [538]	training's auc: 0.9089	valid_1's auc: 0.89315
# [539]	training's auc: 0.90892	valid_1's auc: 0.893156
# [540]	training's auc: 0.908934	valid_1's auc: 0.893153
# [541]	training's auc: 0.908966	valid_1's auc: 0.893154
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [542]	training's auc: 0.908968	valid_1's auc: 0.893154
# [543]	training's auc: 0.908983	valid_1's auc: 0.893156
# [544]	training's auc: 0.909007	valid_1's auc: 0.893159
# [545]	training's auc: 0.909033	valid_1's auc: 0.893155
# [546]	training's auc: 0.909051	valid_1's auc: 0.89316
# [547]	training's auc: 0.909071	valid_1's auc: 0.893162
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [548]	training's auc: 0.909074	valid_1's auc: 0.893165
# [549]	training's auc: 0.909095	valid_1's auc: 0.893161
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [550]	training's auc: 0.909099	valid_1's auc: 0.893165
# [551]	training's auc: 0.909102	valid_1's auc: 0.893169
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [552]	training's auc: 0.909103	valid_1's auc: 0.893169
# [553]	training's auc: 0.909122	valid_1's auc: 0.893171
# [554]	training's auc: 0.909139	valid_1's auc: 0.893174
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [555]	training's auc: 0.909142	valid_1's auc: 0.893176
# [556]	training's auc: 0.909153	valid_1's auc: 0.893174
# [557]	training's auc: 0.909174	valid_1's auc: 0.893175
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [558]	training's auc: 0.909176	valid_1's auc: 0.893178
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [559]	training's auc: 0.909179	valid_1's auc: 0.893178
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [560]	training's auc: 0.909182	valid_1's auc: 0.893179
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [561]	training's auc: 0.909185	valid_1's auc: 0.893183
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [562]	training's auc: 0.909188	valid_1's auc: 0.893186
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [563]	training's auc: 0.90919	valid_1's auc: 0.893188
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [564]	training's auc: 0.909194	valid_1's auc: 0.893193
# [565]	training's auc: 0.909208	valid_1's auc: 0.893196
# [566]	training's auc: 0.909225	valid_1's auc: 0.893197
# [567]	training's auc: 0.909239	valid_1's auc: 0.893197
# [568]	training's auc: 0.909244	valid_1's auc: 0.893202
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [569]	training's auc: 0.909244	valid_1's auc: 0.893201
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [570]	training's auc: 0.909247	valid_1's auc: 0.893204
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [571]	training's auc: 0.909251	valid_1's auc: 0.893208
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [572]	training's auc: 0.909255	valid_1's auc: 0.893212
# [573]	training's auc: 0.909291	valid_1's auc: 0.893219
# [574]	training's auc: 0.909317	valid_1's auc: 0.893221
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [575]	training's auc: 0.909319	valid_1's auc: 0.893224
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [576]	training's auc: 0.909322	valid_1's auc: 0.893226
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [577]	training's auc: 0.909323	valid_1's auc: 0.893226
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [578]	training's auc: 0.909325	valid_1's auc: 0.893229
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [579]	training's auc: 0.909329	valid_1's auc: 0.893232
# [580]	training's auc: 0.909355	valid_1's auc: 0.893233
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [581]	training's auc: 0.909357	valid_1's auc: 0.893236
# [582]	training's auc: 0.909381	valid_1's auc: 0.893238
# [583]	training's auc: 0.9094	valid_1's auc: 0.893243
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [584]	training's auc: 0.909403	valid_1's auc: 0.893246
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [585]	training's auc: 0.909406	valid_1's auc: 0.89325
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [586]	training's auc: 0.909407	valid_1's auc: 0.893251
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [587]	training's auc: 0.90941	valid_1's auc: 0.893256
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [588]	training's auc: 0.909412	valid_1's auc: 0.893257
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [589]	training's auc: 0.909414	valid_1's auc: 0.893261
# [590]	training's auc: 0.909435	valid_1's auc: 0.89326
# [591]	training's auc: 0.909448	valid_1's auc: 0.893261
# [592]	training's auc: 0.909469	valid_1's auc: 0.893265
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [593]	training's auc: 0.909472	valid_1's auc: 0.893269
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [594]	training's auc: 0.909474	valid_1's auc: 0.893271
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [595]	training's auc: 0.909475	valid_1's auc: 0.893271
# [596]	training's auc: 0.909497	valid_1's auc: 0.893267
# [597]	training's auc: 0.909513	valid_1's auc: 0.893265
# [598]	training's auc: 0.909548	valid_1's auc: 0.893268
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [599]	training's auc: 0.909548	valid_1's auc: 0.893268
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [600]	training's auc: 0.909549	valid_1's auc: 0.89327
# [601]	training's auc: 0.909562	valid_1's auc: 0.89327
# [602]	training's auc: 0.909575	valid_1's auc: 0.89327
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [603]	training's auc: 0.909577	valid_1's auc: 0.893271
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [604]	training's auc: 0.909579	valid_1's auc: 0.893273
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [605]	training's auc: 0.909582	valid_1's auc: 0.893272
# [606]	training's auc: 0.909593	valid_1's auc: 0.893268
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [607]	training's auc: 0.909595	valid_1's auc: 0.893269
# [608]	training's auc: 0.90961	valid_1's auc: 0.89327
# [609]	training's auc: 0.909612	valid_1's auc: 0.893274
# [610]	training's auc: 0.909619	valid_1's auc: 0.893273
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [611]	training's auc: 0.909622	valid_1's auc: 0.893275
# [612]	training's auc: 0.909634	valid_1's auc: 0.893275
# [613]	training's auc: 0.909654	valid_1's auc: 0.893275
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [614]	training's auc: 0.909656	valid_1's auc: 0.893278
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [615]	training's auc: 0.909657	valid_1's auc: 0.89328
# [616]	training's auc: 0.909664	valid_1's auc: 0.893277
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [617]	training's auc: 0.909667	valid_1's auc: 0.89328
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [618]	training's auc: 0.90967	valid_1's auc: 0.893282
# [619]	training's auc: 0.909704	valid_1's auc: 0.893285
# [620]	training's auc: 0.909719	valid_1's auc: 0.893284
# [621]	training's auc: 0.909737	valid_1's auc: 0.893283
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [622]	training's auc: 0.909741	valid_1's auc: 0.893284
# [623]	training's auc: 0.909762	valid_1's auc: 0.893286
# [624]	training's auc: 0.909779	valid_1's auc: 0.893284
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [625]	training's auc: 0.90978	valid_1's auc: 0.893286
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [626]	training's auc: 0.909782	valid_1's auc: 0.893287
# [627]	training's auc: 0.909799	valid_1's auc: 0.893285
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [628]	training's auc: 0.909799	valid_1's auc: 0.893285
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [629]	training's auc: 0.9098	valid_1's auc: 0.893286
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [630]	training's auc: 0.909801	valid_1's auc: 0.893286
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [631]	training's auc: 0.909802	valid_1's auc: 0.893286
# [632]	training's auc: 0.909816	valid_1's auc: 0.893288
# [633]	training's auc: 0.909836	valid_1's auc: 0.893287
# [634]	training's auc: 0.909859	valid_1's auc: 0.893288
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [635]	training's auc: 0.909858	valid_1's auc: 0.893288
# [636]	training's auc: 0.909869	valid_1's auc: 0.893282
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [637]	training's auc: 0.909871	valid_1's auc: 0.893284
# [638]	training's auc: 0.909904	valid_1's auc: 0.893289
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [639]	training's auc: 0.909906	valid_1's auc: 0.893288
# [640]	training's auc: 0.909919	valid_1's auc: 0.893289
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [641]	training's auc: 0.909921	valid_1's auc: 0.893289
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [642]	training's auc: 0.909932	valid_1's auc: 0.89329
# [643]	training's auc: 0.909952	valid_1's auc: 0.893288
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [644]	training's auc: 0.909952	valid_1's auc: 0.893288
# [645]	training's auc: 0.909971	valid_1's auc: 0.893287
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [646]	training's auc: 0.909972	valid_1's auc: 0.893287
# [647]	training's auc: 0.909989	valid_1's auc: 0.893285
# [648]	training's auc: 0.910008	valid_1's auc: 0.893286
# [649]	training's auc: 0.910032	valid_1's auc: 0.893281
# [650]	training's auc: 0.910052	valid_1's auc: 0.893281
# [651]	training's auc: 0.910084	valid_1's auc: 0.893286
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [652]	training's auc: 0.910084	valid_1's auc: 0.893287
# [653]	training's auc: 0.910103	valid_1's auc: 0.893281
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [654]	training's auc: 0.910106	valid_1's auc: 0.893282
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [655]	training's auc: 0.910107	valid_1's auc: 0.893284
# [656]	training's auc: 0.91012	valid_1's auc: 0.893284
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [657]	training's auc: 0.910122	valid_1's auc: 0.893286
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [658]	training's auc: 0.910122	valid_1's auc: 0.893286
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [659]	training's auc: 0.910124	valid_1's auc: 0.893287
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [660]	training's auc: 0.910124	valid_1's auc: 0.893288
# [661]	training's auc: 0.910142	valid_1's auc: 0.893287
# [662]	training's auc: 0.910154	valid_1's auc: 0.893286
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [663]	training's auc: 0.910154	valid_1's auc: 0.893286
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [664]	training's auc: 0.910155	valid_1's auc: 0.893286
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [665]	training's auc: 0.910156	valid_1's auc: 0.893288
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [666]	training's auc: 0.910156	valid_1's auc: 0.893289
# [667]	training's auc: 0.910168	valid_1's auc: 0.893288
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [668]	training's auc: 0.910167	valid_1's auc: 0.893289
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [669]	training's auc: 0.910169	valid_1's auc: 0.89329
# [670]	training's auc: 0.910184	valid_1's auc: 0.893288
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [671]	training's auc: 0.910184	valid_1's auc: 0.893288
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [672]	training's auc: 0.910185	valid_1's auc: 0.893289
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [673]	training's auc: 0.910185	valid_1's auc: 0.893291
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [674]	training's auc: 0.910185	valid_1's auc: 0.893291
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [675]	training's auc: 0.910186	valid_1's auc: 0.893291
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [676]	training's auc: 0.910186	valid_1's auc: 0.893291
# [677]	training's auc: 0.910198	valid_1's auc: 0.89329
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [678]	training's auc: 0.910197	valid_1's auc: 0.89329
# [679]	training's auc: 0.910219	valid_1's auc: 0.893289
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [680]	training's auc: 0.910219	valid_1's auc: 0.893289
# [681]	training's auc: 0.910232	valid_1's auc: 0.89329
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [682]	training's auc: 0.910233	valid_1's auc: 0.893291
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [683]	training's auc: 0.910233	valid_1's auc: 0.893292
# [684]	training's auc: 0.910253	valid_1's auc: 0.893295
# [685]	training's auc: 0.910278	valid_1's auc: 0.893296
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [686]	training's auc: 0.910278	valid_1's auc: 0.893296
# [687]	training's auc: 0.9103	valid_1's auc: 0.893299
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [688]	training's auc: 0.910302	valid_1's auc: 0.893299
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [689]	training's auc: 0.910302	valid_1's auc: 0.893299
# [690]	training's auc: 0.910323	valid_1's auc: 0.893293
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [691]	training's auc: 0.910324	valid_1's auc: 0.893293
# [692]	training's auc: 0.910337	valid_1's auc: 0.893294
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [693]	training's auc: 0.910337	valid_1's auc: 0.893294
# [694]	training's auc: 0.91035	valid_1's auc: 0.893294
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [695]	training's auc: 0.91035	valid_1's auc: 0.893294
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [696]	training's auc: 0.91035	valid_1's auc: 0.893294
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [697]	training's auc: 0.91035	valid_1's auc: 0.893294
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [698]	training's auc: 0.91035	valid_1's auc: 0.893294
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [699]	training's auc: 0.91035	valid_1's auc: 0.893294
# [700]	training's auc: 0.91037	valid_1's auc: 0.89329
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [701]	training's auc: 0.91037	valid_1's auc: 0.89329
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [702]	training's auc: 0.91037	valid_1's auc: 0.893291
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [703]	training's auc: 0.91037	valid_1's auc: 0.893291
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [704]	training's auc: 0.91037	valid_1's auc: 0.893291
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [705]	training's auc: 0.91037	valid_1's auc: 0.893291
# [706]	training's auc: 0.91038	valid_1's auc: 0.89329
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [707]	training's auc: 0.910379	valid_1's auc: 0.89329
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [708]	training's auc: 0.91038	valid_1's auc: 0.89329
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [709]	training's auc: 0.91038	valid_1's auc: 0.893291
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [710]	training's auc: 0.91038	valid_1's auc: 0.893291
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [711]	training's auc: 0.910381	valid_1's auc: 0.893292
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [712]	training's auc: 0.910385	valid_1's auc: 0.893293
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [713]	training's auc: 0.910385	valid_1's auc: 0.893293
# [714]	training's auc: 0.910404	valid_1's auc: 0.893294
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [715]	training's auc: 0.910404	valid_1's auc: 0.893294
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [716]	training's auc: 0.910404	valid_1's auc: 0.893295
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [717]	training's auc: 0.910404	valid_1's auc: 0.893295
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [718]	training's auc: 0.910404	valid_1's auc: 0.893295
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [719]	training's auc: 0.910404	valid_1's auc: 0.893295
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [720]	training's auc: 0.910404	valid_1's auc: 0.893295
# [721]	training's auc: 0.910419	valid_1's auc: 0.893294
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [722]	training's auc: 0.910419	valid_1's auc: 0.893294
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [723]	training's auc: 0.910419	valid_1's auc: 0.893294
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [724]	training's auc: 0.910419	valid_1's auc: 0.893295
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [725]	training's auc: 0.910419	valid_1's auc: 0.893296
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [726]	training's auc: 0.910419	valid_1's auc: 0.893296
# [727]	training's auc: 0.910435	valid_1's auc: 0.893297
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [728]	training's auc: 0.910435	valid_1's auc: 0.893297
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [729]	training's auc: 0.910435	valid_1's auc: 0.893297
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [730]	training's auc: 0.910435	valid_1's auc: 0.893297
# [731]	training's auc: 0.910454	valid_1's auc: 0.8933
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [732]	training's auc: 0.910455	valid_1's auc: 0.893301
# [733]	training's auc: 0.910471	valid_1's auc: 0.8933
# [734]	training's auc: 0.910484	valid_1's auc: 0.893297
# [735]	training's auc: 0.910496	valid_1's auc: 0.893294
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [736]	training's auc: 0.910496	valid_1's auc: 0.893294
# [737]	training's auc: 0.910506	valid_1's auc: 0.893294
# [738]	training's auc: 0.910532	valid_1's auc: 0.893293
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [739]	training's auc: 0.910532	valid_1's auc: 0.893293
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [740]	training's auc: 0.910532	valid_1's auc: 0.893293
# [741]	training's auc: 0.91055	valid_1's auc: 0.893292
# [742]	training's auc: 0.910562	valid_1's auc: 0.893291
# [743]	training's auc: 0.910572	valid_1's auc: 0.893288
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [744]	training's auc: 0.910573	valid_1's auc: 0.893288
# [745]	training's auc: 0.910591	valid_1's auc: 0.893286
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [746]	training's auc: 0.910593	valid_1's auc: 0.893288
# [747]	training's auc: 0.910606	valid_1's auc: 0.893282
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [748]	training's auc: 0.910606	valid_1's auc: 0.893282
# [749]	training's auc: 0.91062	valid_1's auc: 0.893283
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [750]	training's auc: 0.91062	valid_1's auc: 0.893283
# [751]	training's auc: 0.91063	valid_1's auc: 0.893282
# [752]	training's auc: 0.910646	valid_1's auc: 0.893284
# [753]	training's auc: 0.910655	valid_1's auc: 0.893282
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [754]	training's auc: 0.910655	valid_1's auc: 0.893282
# [755]	training's auc: 0.910668	valid_1's auc: 0.893279
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [756]	training's auc: 0.910668	valid_1's auc: 0.893279
# [757]	training's auc: 0.910683	valid_1's auc: 0.893278
# [758]	training's auc: 0.910697	valid_1's auc: 0.893274
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [759]	training's auc: 0.910697	valid_1's auc: 0.893273
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [760]	training's auc: 0.910697	valid_1's auc: 0.893273
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [761]	training's auc: 0.910697	valid_1's auc: 0.893273
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [762]	training's auc: 0.910697	valid_1's auc: 0.893273
# [763]	training's auc: 0.910708	valid_1's auc: 0.893274
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [764]	training's auc: 0.910707	valid_1's auc: 0.893275
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [765]	training's auc: 0.910707	valid_1's auc: 0.893276
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [766]	training's auc: 0.910707	valid_1's auc: 0.893276
# [767]	training's auc: 0.910716	valid_1's auc: 0.89327
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [768]	training's auc: 0.910716	valid_1's auc: 0.89327
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [769]	training's auc: 0.910716	valid_1's auc: 0.89327
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [770]	training's auc: 0.910716	valid_1's auc: 0.89327
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [771]	training's auc: 0.910716	valid_1's auc: 0.89327
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [772]	training's auc: 0.910716	valid_1's auc: 0.89327
# [773]	training's auc: 0.910728	valid_1's auc: 0.893265
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [774]	training's auc: 0.910728	valid_1's auc: 0.893265
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [775]	training's auc: 0.910728	valid_1's auc: 0.893265
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [776]	training's auc: 0.910728	valid_1's auc: 0.893267
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [777]	training's auc: 0.910728	valid_1's auc: 0.893267
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [778]	training's auc: 0.910728	valid_1's auc: 0.893267
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [779]	training's auc: 0.910728	valid_1's auc: 0.893267
# [780]	training's auc: 0.91074	valid_1's auc: 0.893266
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [781]	training's auc: 0.91074	valid_1's auc: 0.893266
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [782]	training's auc: 0.910743	valid_1's auc: 0.893266
# ...
# [605]	training's auc: 0.909317	valid_1's auc: 0.894334
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [606]	training's auc: 0.909316	valid_1's auc: 0.894334
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [607]	training's auc: 0.909317	valid_1's auc: 0.894335
# [608]	training's auc: 0.909339	valid_1's auc: 0.894332
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [609]	training's auc: 0.909341	valid_1's auc: 0.894332
# [610]	training's auc: 0.90936	valid_1's auc: 0.894333
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [611]	training's auc: 0.909362	valid_1's auc: 0.894335
# [612]	training's auc: 0.909378	valid_1's auc: 0.89433
# [613]	training's auc: 0.909403	valid_1's auc: 0.894336
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [614]	training's auc: 0.909404	valid_1's auc: 0.894339
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [615]	training's auc: 0.909405	valid_1's auc: 0.894339
# [616]	training's auc: 0.909417	valid_1's auc: 0.894334
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [617]	training's auc: 0.909418	valid_1's auc: 0.894334
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [618]	training's auc: 0.909419	valid_1's auc: 0.894334
# [619]	training's auc: 0.909449	valid_1's auc: 0.894332
# [620]	training's auc: 0.909465	valid_1's auc: 0.894329
# [621]	training's auc: 0.909484	valid_1's auc: 0.894324
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [622]	training's auc: 0.909486	valid_1's auc: 0.894325
# [623]	training's auc: 0.909503	valid_1's auc: 0.894321
# [624]	training's auc: 0.909518	valid_1's auc: 0.894315
# [625]	training's auc: 0.909519	valid_1's auc: 0.894315
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [626]	training's auc: 0.90952	valid_1's auc: 0.894317
# [627]	training's auc: 0.909537	valid_1's auc: 0.894312
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [628]	training's auc: 0.909538	valid_1's auc: 0.894314
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [629]	training's auc: 0.909539	valid_1's auc: 0.894315
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [630]	training's auc: 0.909541	valid_1's auc: 0.894316
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [631]	training's auc: 0.909541	valid_1's auc: 0.894317
# [632]	training's auc: 0.909552	valid_1's auc: 0.89431
# [633]	training's auc: 0.909565	valid_1's auc: 0.894309
# [634]	training's auc: 0.90958	valid_1's auc: 0.894303
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [635]	training's auc: 0.909581	valid_1's auc: 0.894303
# [636]	training's auc: 0.909596	valid_1's auc: 0.894299
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [637]	training's auc: 0.909598	valid_1's auc: 0.8943
# [638]	training's auc: 0.909612	valid_1's auc: 0.894297
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [639]	training's auc: 0.909613	valid_1's auc: 0.894298
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [640]	training's auc: 0.909613	valid_1's auc: 0.894298
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [641]	training's auc: 0.909613	valid_1's auc: 0.894298
# [642]	training's auc: 0.909628	valid_1's auc: 0.894292
# [643]	training's auc: 0.90964	valid_1's auc: 0.894291
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [644]	training's auc: 0.909642	valid_1's auc: 0.894293
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [645]	training's auc: 0.909642	valid_1's auc: 0.894293
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [646]	training's auc: 0.909642	valid_1's auc: 0.894293
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [647]	training's auc: 0.909642	valid_1's auc: 0.894293
# [648]	training's auc: 0.909658	valid_1's auc: 0.894291
# [649]	training's auc: 0.90967	valid_1's auc: 0.894289
# [650]	training's auc: 0.909687	valid_1's auc: 0.894289
# [651]	training's auc: 0.9097	valid_1's auc: 0.89429
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [652]	training's auc: 0.909701	valid_1's auc: 0.89429
# [653]	training's auc: 0.909713	valid_1's auc: 0.894285
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [654]	training's auc: 0.909712	valid_1's auc: 0.894286
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [655]	training's auc: 0.909712	valid_1's auc: 0.894286
# [656]	training's auc: 0.909745	valid_1's auc: 0.894286
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [657]	training's auc: 0.909745	valid_1's auc: 0.894286
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [658]	training's auc: 0.909745	valid_1's auc: 0.894287
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [659]	training's auc: 0.909746	valid_1's auc: 0.894288
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [660]	training's auc: 0.909746	valid_1's auc: 0.894289
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [661]	training's auc: 0.909747	valid_1's auc: 0.894289
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [662]	training's auc: 0.909747	valid_1's auc: 0.894289
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [663]	training's auc: 0.909748	valid_1's auc: 0.89429
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [664]	training's auc: 0.909749	valid_1's auc: 0.894292
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [665]	training's auc: 0.90975	valid_1's auc: 0.894292
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [666]	training's auc: 0.90975	valid_1's auc: 0.894292
# [667]	training's auc: 0.909766	valid_1's auc: 0.89429
# [668]	training's auc: 0.909785	valid_1's auc: 0.89429
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [669]	training's auc: 0.909787	valid_1's auc: 0.89429
# [670]	training's auc: 0.909797	valid_1's auc: 0.894284
# [671]	training's auc: 0.909829	valid_1's auc: 0.894284
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [672]	training's auc: 0.909829	valid_1's auc: 0.894284
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [673]	training's auc: 0.909829	valid_1's auc: 0.894284
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [674]	training's auc: 0.909829	valid_1's auc: 0.894284
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [675]	training's auc: 0.909829	valid_1's auc: 0.894284
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [676]	training's auc: 0.909829	valid_1's auc: 0.894284
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [677]	training's auc: 0.909829	valid_1's auc: 0.894284
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [678]	training's auc: 0.909829	valid_1's auc: 0.894284
# [679]	training's auc: 0.90984	valid_1's auc: 0.894277
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [680]	training's auc: 0.909841	valid_1's auc: 0.894277
# [681]	training's auc: 0.909853	valid_1's auc: 0.894274
# [682]	training's auc: 0.909874	valid_1's auc: 0.894269
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [683]	training's auc: 0.909875	valid_1's auc: 0.894272
# [684]	training's auc: 0.909889	valid_1's auc: 0.894267
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [685]	training's auc: 0.909889	valid_1's auc: 0.894267
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [686]	training's auc: 0.90989	valid_1's auc: 0.894268
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [687]	training's auc: 0.90989	valid_1's auc: 0.894269
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [688]	training's auc: 0.90989	valid_1's auc: 0.894269
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [689]	training's auc: 0.90989	valid_1's auc: 0.894269
# [690]	training's auc: 0.909905	valid_1's auc: 0.89427
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [691]	training's auc: 0.909905	valid_1's auc: 0.89427
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [692]	training's auc: 0.909905	valid_1's auc: 0.89427
# [693]	training's auc: 0.909918	valid_1's auc: 0.894266
# [694]	training's auc: 0.909926	valid_1's auc: 0.894261
# [695]	training's auc: 0.909957	valid_1's auc: 0.894262
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [696]	training's auc: 0.909957	valid_1's auc: 0.894263
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [697]	training's auc: 0.909957	valid_1's auc: 0.894263
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [698]	training's auc: 0.909957	valid_1's auc: 0.894263
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [699]	training's auc: 0.909957	valid_1's auc: 0.894263
# [700]	training's auc: 0.909968	valid_1's auc: 0.894259
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [701]	training's auc: 0.909971	valid_1's auc: 0.894261
# [702]	training's auc: 0.909984	valid_1's auc: 0.894254
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [703]	training's auc: 0.909984	valid_1's auc: 0.894254
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [704]	training's auc: 0.909984	valid_1's auc: 0.894254
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [705]	training's auc: 0.909984	valid_1's auc: 0.894254
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [706]	training's auc: 0.909984	valid_1's auc: 0.894254
# [707]	training's auc: 0.909996	valid_1's auc: 0.894249
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [708]	training's auc: 0.909996	valid_1's auc: 0.894249
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [709]	training's auc: 0.909996	valid_1's auc: 0.894249
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [710]	training's auc: 0.909996	valid_1's auc: 0.894249
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [711]	training's auc: 0.909996	valid_1's auc: 0.894249
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [712]	training's auc: 0.909997	valid_1's auc: 0.89425
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Stopped training because there are no more leaves that meet the split requirements
# [713]	training's auc: 0.909997	valid_1's auc: 0.89425
# [714]	training's auc: 0.91001	valid_1's auc: 0.894246
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [715]	training's auc: 0.910011	valid_1's auc: 0.894246
# Early stopping, best iteration is:
# [615]	training's auc: 0.909405	valid_1's auc: 0.894339
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=0.000911024108147967, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=0.000911024108147967
# [LightGBM] [Warning] min_data_in_leaf is set=198, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=198
# [LightGBM] [Warning] feature_fraction is set=0.5040305717020102, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5040305717020102
# [LightGBM] [Warning] lambda_l2 is set=34.144257057990224, reg_lambda=0.0 will be ignored. Current value: lambda_l2=34.144257057990224
# [LightGBM] [Warning] lambda_l1 is set=74.98841302101062, reg_alpha=0.0 will be ignored. Current value: lambda_l1=74.98841302101062
# [LightGBM] [Warning] bagging_fraction is set=0.9940542446575642, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9940542446575642
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=0.000911024108147967, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=0.000911024108147967
# [LightGBM] [Warning] min_data_in_leaf is set=198, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=198
# [LightGBM] [Warning] feature_fraction is set=0.5040305717020102, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5040305717020102
# [LightGBM] [Warning] lambda_l2 is set=34.144257057990224, reg_lambda=0.0 will be ignored. Current value: lambda_l2=34.144257057990224
# [LightGBM] [Warning] lambda_l1 is set=74.98841302101062, reg_alpha=0.0 will be ignored. Current value: lambda_l1=74.98841302101062
# [LightGBM] [Warning] bagging_fraction is set=0.9940542446575642, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9940542446575642
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [accuracy] tr: 0.91, va: 0.89
# -------------------- result --------------------
# [[0.         0.9107076  0.89327438]
#  [1.         0.9090104  0.89649966]
#  [2.         0.9093581  0.89572529]
#  [3.         0.90967795 0.89360599]
#  [4.         0.90940515 0.89433874]]
# [cv ] tr: 0.91+-0.00, va: 0.89+-0.00
# Done.

# %% [markdown]
# 学習モデルによる推論

# %%
y_test_pred = model.predict_proba(x_test)
# Out:
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=0.000911024108147967, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=0.000911024108147967
# [LightGBM] [Warning] min_data_in_leaf is set=198, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=198
# [LightGBM] [Warning] feature_fraction is set=0.5040305717020102, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5040305717020102
# [LightGBM] [Warning] lambda_l2 is set=34.144257057990224, reg_lambda=0.0 will be ignored. Current value: lambda_l2=34.144257057990224
# [LightGBM] [Warning] lambda_l1 is set=74.98841302101062, reg_alpha=0.0 will be ignored. Current value: lambda_l1=74.98841302101062
# [LightGBM] [Warning] bagging_fraction is set=0.9940542446575642, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9940542446575642
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1

# %% [markdown]
# 提出用ファイルの作成

# %%
df_submit = pd.DataFrame({"id": id_test["id"], "Exited": y_test_pred[:, 1]})
display(df_submit.head(5))
df_submit.to_csv("/content/drive/MyDrive/kaggle実践/銀行解約データセットを使用した二項分類/submission_optuna.csv", index=None)
# Out:
#        id    Exited
# 0  165034  0.011625
# 1  165035  0.662486
# 2  165036  0.019860
# 3  165037  0.246090
# 4  165038  0.402806
